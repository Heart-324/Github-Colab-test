# %% [markdown]
# <a href="https://colab.research.google.com/github/Heart-324/Github-Colab-test/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch import nn
from torch.nn import Flatten, Linear
from torch.utils.data import DataLoader
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter

train_data = torchvision.datasets.CIFAR10(root="./dataset2", train=True, download=True,
                                       transform=torchvision.transforms.ToTensor())
test_data = torchvision.datasets.CIFAR10(root="./dataset2", train=False, download=True,
                                       transform=torchvision.transforms.ToTensor())
train_loader = torch.utils.data.DataLoader(train_data, batch_size=64,
                                          shuffle=True, num_workers=0)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=64,
                                          shuffle=True, num_workers=0)

train_data_size = len(train_data)
test_data_size = len(test_data)
print(f"训练数据集的长度为{train_data_size}")
print(f"测试数据集的长度为{test_data_size}")


# 搭建神经网络
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, 3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, 3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(128 * 4 * 4, 256)
        self.fc2 = nn.Linear(256, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = x.view(-1, 128 * 4 * 4)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x


model = SimpleCNN()

criterion = nn.CrossEntropyLoss()  # 损失函数为交叉熵损失
optimizer = optim.Adam(model.parameters(), lr=0.001)  # 优化器为 Adam

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model.to(device)

# 添加tensorboard
writer = SummaryWriter("logs")

# 训练和评估时将数据也移动到 GPU 上
total_train_step = 0  # 记录训练的次数
total_test_step = 0  # 记录测试的次数
num_epochs = 10  # 总共训练轮次
for epoch in range(num_epochs):
    print(f"-----------------------第{epoch+1}轮训练开始啦-------------------------")
    for data in train_loader:
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        total_train_step += 1
        if total_train_step % 100 == 0:
            print(f"训练次数为{total_train_step}, 本次损失值为{loss.item()}")
            writer.add_scalar("train_loss", loss.item(), total_train_step)

    total_test_loss = 0
    with torch.no_grad():  # 在with这部分代码里面就没有梯度了
        for data in test_loader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)  # 把他放到
            outputs = model(images)
            loss = loss = criterion(outputs, labels)
            total_test_loss = total_test_loss + loss.item()
    print(f"这是第{epoch+1}轮训练，这轮训练的总损失为{total_test_loss}")
    writer.add_scalar("test_loss", total_test_loss, total_test_step)
    total_test_step += 1

writer.close()
print("完成训练")


# !nvidia-smi
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./dataset2/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:19<00:00, 8705898.49it/s]
# Extracting ./dataset2/cifar-10-python.tar.gz to ./dataset2
# Files already downloaded and verified
# 训练数据集的长度为50000
# 测试数据集的长度为10000
# -----------------------第1轮训练开始啦-------------------------
# 训练次数为100, 本次损失值为1.8029661178588867
# 训练次数为200, 本次损失值为1.6779859066009521
# 训练次数为300, 本次损失值为1.5182173252105713
# 训练次数为400, 本次损失值为1.3430742025375366
# 训练次数为500, 本次损失值为1.4344594478607178
# 训练次数为600, 本次损失值为1.2093429565429688
# 训练次数为700, 本次损失值为1.3049260377883911
# 这是第1轮训练，这轮训练的总损失为205.6688956618309
# -----------------------第2轮训练开始啦-------------------------
# 训练次数为800, 本次损失值为1.209341049194336
# 训练次数为900, 本次损失值为1.0791298151016235
# 训练次数为1000, 本次损失值为1.2843509912490845
# 训练次数为1100, 本次损失值为1.0110465288162231
# 训练次数为1200, 本次损失值为0.8713252544403076
# 训练次数为1300, 本次损失值为1.1280224323272705
# 训练次数为1400, 本次损失值为0.9636546969413757
# 训练次数为1500, 本次损失值为0.9173858761787415
# 这是第2轮训练，这轮训练的总损失为161.58289223909378
# -----------------------第3轮训练开始啦-------------------------
# 训练次数为1600, 本次损失值为0.9858154654502869
# 训练次数为1700, 本次损失值为0.7975611090660095
# 训练次数为1800, 本次损失值为0.8795336484909058
# 训练次数为1900, 本次损失值为1.1000953912734985
# 训练次数为2000, 本次损失值为0.9558617472648621
# 训练次数为2100, 本次损失值为0.6799624562263489
# 训练次数为2200, 本次损失值为0.7840006947517395
# 训练次数为2300, 本次损失值为0.6962285041809082
# 这是第3轮训练，这轮训练的总损失为139.12700194120407
# -----------------------第4轮训练开始啦-------------------------
# 训练次数为2400, 本次损失值为0.9754868149757385
# 训练次数为2500, 本次损失值为0.8290857672691345
# 训练次数为2600, 本次损失值为0.6659541726112366
# 训练次数为2700, 本次损失值为0.8536616563796997
# 训练次数为2800, 本次损失值为0.8540680408477783
# 训练次数为2900, 本次损失值为0.7593948841094971
# 训练次数为3000, 本次损失值为0.7332210540771484
# 训练次数为3100, 本次损失值为0.6822751760482788
# 这是第4轮训练，这轮训练的总损失为127.81477922201157
# -----------------------第5轮训练开始啦-------------------------
# 训练次数为3200, 本次损失值为0.7896002531051636
# 训练次数为3300, 本次损失值为0.5728160738945007
# 训练次数为3400, 本次损失值为0.8199529051780701
# 训练次数为3500, 本次损失值为0.5883101224899292
# 训练次数为3600, 本次损失值为0.5192480087280273
# 训练次数为3700, 本次损失值为0.733161449432373
# 训练次数为3800, 本次损失值为0.6494860053062439
# 训练次数为3900, 本次损失值为0.6424080729484558
# 这是第5轮训练，这轮训练的总损失为121.57621523737907
# -----------------------第6轮训练开始啦-------------------------
# 训练次数为4000, 本次损失值为0.8400742411613464
# 训练次数为4100, 本次损失值为0.5367072820663452
# 训练次数为4200, 本次损失值为0.42504018545150757
# 训练次数为4300, 本次损失值为0.7802448272705078
# 训练次数为4400, 本次损失值为0.6168709993362427
# 训练次数为4500, 本次损失值为0.7404526472091675
# 训练次数为4600, 本次损失值为0.6033062934875488
# 这是第6轮训练，这轮训练的总损失为129.5456654727459
# -----------------------第7轮训练开始啦-------------------------
# 训练次数为4700, 本次损失值为0.48238539695739746
# 训练次数为4800, 本次损失值为0.2987341582775116
# 训练次数为4900, 本次损失值为0.441240131855011
# 训练次数为5000, 本次损失值为0.4629785716533661
# 训练次数为5100, 本次损失值为0.3929256200790405
# 训练次数为5200, 本次损失值为0.6508244872093201
# 训练次数为5300, 本次损失值为0.46456581354141235
# 训练次数为5400, 本次损失值为0.5187430381774902
# 这是第7轮训练，这轮训练的总损失为123.17296436429024
# -----------------------第8轮训练开始啦-------------------------
# 训练次数为5500, 本次损失值为0.4600858688354492
# 训练次数为5600, 本次损失值为0.40804094076156616
# 训练次数为5700, 本次损失值为0.4791956841945648
# 训练次数为5800, 本次损失值为0.3587833344936371
# 训练次数为5900, 本次损失值为0.48187556862831116
# 训练次数为6000, 本次损失值为0.3444899320602417
# 训练次数为6100, 本次损失值为0.5122697353363037
# 训练次数为6200, 本次损失值为0.5273106694221497
# 这是第8轮训练，这轮训练的总损失为126.38000452518463
# -----------------------第9轮训练开始啦-------------------------
# 训练次数为6300, 本次损失值为0.5237149000167847
# 训练次数为6400, 本次损失值为0.2820708155632019
# 训练次数为6500, 本次损失值为0.2590077817440033
# 训练次数为6600, 本次损失值为0.36360177397727966
# 训练次数为6700, 本次损失值为0.49470919370651245
# 训练次数为6800, 本次损失值为0.5187286138534546
# 训练次数为6900, 本次损失值为0.3558690547943115
# 训练次数为7000, 本次损失值为0.3386174738407135
# 这是第9轮训练，这轮训练的总损失为129.85963770747185
# -----------------------第10轮训练开始啦-------------------------
# 训练次数为7100, 本次损失值为0.2569752335548401
# 训练次数为7200, 本次损失值为0.33924317359924316
# 训练次数为7300, 本次损失值为0.3881312906742096
# 训练次数为7400, 本次损失值为0.36477965116500854
# 训练次数为7500, 本次损失值为0.4855521619319916
# 训练次数为7600, 本次损失值为0.38489946722984314
# 训练次数为7700, 本次损失值为0.5080806612968445
# 训练次数为7800, 本次损失值为0.3598155379295349
# 这是第10轮训练，这轮训练的总损失为139.0767111480236
# 完成训练

# %%
# !nvidia-smi
# Out:
# Thu Aug 15 01:37:40 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P0              30W /  70W |    279MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch import nn
from torch.nn import Flatten, Linear
from torch.utils.data import DataLoader
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter

train_data = torchvision.datasets.CIFAR10(root="./dataset2", train=True, download=True,
                                       transform=torchvision.transforms.ToTensor())
test_data = torchvision.datasets.CIFAR10(root="./dataset2", train=False, download=True,
                                       transform=torchvision.transforms.ToTensor())
train_loader = torch.utils.data.DataLoader(train_data, batch_size=64,
                                          shuffle=True, num_workers=0)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=64,
                                          shuffle=True, num_workers=0)

train_data_size = len(train_data)
test_data_size = len(test_data)
print(f"训练数据集的长度为{train_data_size}")
print(f"测试数据集的长度为{test_data_size}")


# 搭建神经网络
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, 3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, 3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(128 * 4 * 4, 256)
        self.fc2 = nn.Linear(256, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = x.view(-1, 128 * 4 * 4)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x


model = SimpleCNN()

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model.to(device)
criterion = nn.CrossEntropyLoss()  # 损失函数为交叉熵损失
optimizer = optim.Adam(model.parameters(), lr=0.001)  # 优化器为 Adam
criterion = criterion.to(device)

# 添加tensorboard
writer = SummaryWriter("logs")

# 训练和评估时将数据也移动到 GPU 上
total_train_step = 0  # 记录训练的次数
total_test_step = 0  # 记录测试的次数
num_epochs = 20  # 总共训练轮次
for epoch in range(num_epochs):
    print(f"-----------------------第{epoch+1}轮训练开始啦-------------------------")
    for data in train_loader:
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        total_train_step += 1
        if total_train_step % 100 == 0:
            print(f"训练次数为{total_train_step}, 本次损失值为{loss.item()}")
            writer.add_scalar("train_loss", loss.item(), total_train_step)

    total_test_loss = 0
    with torch.no_grad():  # 在with这部分代码里面就没有梯度了
        for data in test_loader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)  # 把他放到
            outputs = model(images)
            loss = loss = criterion(outputs, labels)
            total_test_loss = total_test_loss + loss.item()
    print(f"这是第{epoch+1}轮训练，这轮训练的总损失为{total_test_loss}")
    writer.add_scalar("test_loss", total_test_loss, total_test_step)
    total_test_step += 1


    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for data in test_loader:
            inputs, labels = data
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = correct / total
    print(f'Test Accuracy: {accuracy * 100:.2f}%')
    # 假w设你的模型名为 model
    torch.save(model.state_dict(), 'model.pth')
    print("模型已保存")

writer.close()
print("完成训练")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 训练数据集的长度为50000
# 测试数据集的长度为10000
# -----------------------第1轮训练开始啦-------------------------
# 训练次数为100, 本次损失值为1.8479124307632446
# 训练次数为200, 本次损失值为1.6393190622329712
# 训练次数为300, 本次损失值为1.4435068368911743
# 训练次数为400, 本次损失值为1.5115337371826172
# 训练次数为500, 本次损失值为1.6392416954040527
# 训练次数为600, 本次损失值为1.2647907733917236
# 训练次数为700, 本次损失值为1.4358268976211548
# 这是第1轮训练，这轮训练的总损失为190.98722219467163
# Test Accuracy: 55.76%
# 模型已保存
# -----------------------第2轮训练开始啦-------------------------
# 训练次数为800, 本次损失值为1.2469762563705444
# 训练次数为900, 本次损失值为1.0227677822113037
# 训练次数为1000, 本次损失值为1.2166953086853027
# 训练次数为1100, 本次损失值为0.9983175992965698
# 训练次数为1200, 本次损失值为0.9905014038085938
# 训练次数为1300, 本次损失值为1.058372139930725
# 训练次数为1400, 本次损失值为1.424336552619934
# 训练次数为1500, 本次损失值为1.0200849771499634
# 这是第2轮训练，这轮训练的总损失为161.23038792610168
# Test Accuracy: 63.37%
# 模型已保存
# -----------------------第3轮训练开始啦-------------------------
# 训练次数为1600, 本次损失值为0.9795495271682739
# 训练次数为1700, 本次损失值为0.7634055018424988
# 训练次数为1800, 本次损失值为0.9396297931671143
# 训练次数为1900, 本次损失值为1.1643974781036377
# 训练次数为2000, 本次损失值为0.7420180439949036
# 训练次数为2100, 本次损失值为0.8910773396492004
# 训练次数为2200, 本次损失值为0.8978637456893921
# 训练次数为2300, 本次损失值为0.9520170092582703
# 这是第3轮训练，这轮训练的总损失为148.34437668323517
# Test Accuracy: 67.30%
# 模型已保存
# -----------------------第4轮训练开始啦-------------------------
# 训练次数为2400, 本次损失值为0.8309793472290039
# 训练次数为2500, 本次损失值为0.7160704135894775
# 训练次数为2600, 本次损失值为0.7271724343299866
# 训练次数为2700, 本次损失值为0.9197509288787842
# 训练次数为2800, 本次损失值为0.9256769418716431
# 训练次数为2900, 本次损失值为0.6895745992660522
# 训练次数为3000, 本次损失值为0.7429953217506409
# 训练次数为3100, 本次损失值为0.7693415284156799
# 这是第4轮训练，这轮训练的总损失为132.1589874625206
# Test Accuracy: 70.82%
# 模型已保存
# -----------------------第5轮训练开始啦-------------------------
# 训练次数为3200, 本次损失值为0.6564545631408691
# 训练次数为3300, 本次损失值为0.708491861820221
# 训练次数为3400, 本次损失值为0.8230111002922058
# 训练次数为3500, 本次损失值为1.0640124082565308
# 训练次数为3600, 本次损失值为0.8637056350708008
# 训练次数为3700, 本次损失值为0.5364699959754944
# 训练次数为3800, 本次损失值为0.4702254831790924
# 训练次数为3900, 本次损失值为0.5122146606445312
# 这是第5轮训练，这轮训练的总损失为136.6650232076645
# Test Accuracy: 70.06%
# 模型已保存
# -----------------------第6轮训练开始啦-------------------------
# 训练次数为4000, 本次损失值为0.4995115101337433
# 训练次数为4100, 本次损失值为0.5558913946151733
# 训练次数为4200, 本次损失值为0.6947550177574158
# 训练次数为4300, 本次损失值为0.565862238407135
# 训练次数为4400, 本次损失值为0.5480262041091919
# 训练次数为4500, 本次损失值为0.5828800797462463
# 训练次数为4600, 本次损失值为0.5870375633239746
# 这是第6轮训练，这轮训练的总损失为130.08964973688126
# Test Accuracy: 71.96%
# 模型已保存
# -----------------------第7轮训练开始啦-------------------------
# 训练次数为4700, 本次损失值为0.6067237257957458
# 训练次数为4800, 本次损失值为0.612922728061676
# 训练次数为4900, 本次损失值为0.6296921968460083
# 训练次数为5000, 本次损失值为0.5099427103996277
# 训练次数为5100, 本次损失值为0.5372905731201172
# 训练次数为5200, 本次损失值为0.39747461676597595
# 训练次数为5300, 本次损失值为0.49903005361557007
# 训练次数为5400, 本次损失值为0.6048123240470886
# 这是第7轮训练，这轮训练的总损失为136.18049091100693
# Test Accuracy: 70.51%
# 模型已保存
# -----------------------第8轮训练开始啦-------------------------
# 训练次数为5500, 本次损失值为0.442899227142334
# 训练次数为5600, 本次损失值为0.34495824575424194
# 训练次数为5700, 本次损失值为0.5012149214744568
# 训练次数为5800, 本次损失值为0.45166629552841187
# 训练次数为5900, 本次损失值为0.40405547618865967
# 训练次数为6000, 本次损失值为0.37989741563796997
# 训练次数为6100, 本次损失值为0.37753722071647644
# 训练次数为6200, 本次损失值为0.4207274317741394
# 这是第8轮训练，这轮训练的总损失为131.25048527121544
# Test Accuracy: 72.69%
# 模型已保存
# -----------------------第9轮训练开始啦-------------------------
# 训练次数为6300, 本次损失值为0.22527876496315002
# 训练次数为6400, 本次损失值为0.3972480595111847
# 训练次数为6500, 本次损失值为0.26734721660614014
# 训练次数为6600, 本次损失值为0.3341769874095917
# 训练次数为6700, 本次损失值为0.3169167935848236
# 训练次数为6800, 本次损失值为0.5540778040885925
# 训练次数为6900, 本次损失值为0.3031786382198334
# 训练次数为7000, 本次损失值为0.42017582058906555
# 这是第9轮训练，这轮训练的总损失为136.13113695383072
# Test Accuracy: 73.80%
# 模型已保存
# -----------------------第10轮训练开始啦-------------------------
# 训练次数为7100, 本次损失值为0.15915293991565704
# 训练次数为7200, 本次损失值为0.4268517792224884
# 训练次数为7300, 本次损失值为0.3398797810077667
# 训练次数为7400, 本次损失值为0.30077579617500305
# 训练次数为7500, 本次损失值为0.25079360604286194
# 训练次数为7600, 本次损失值为0.4595106840133667
# 训练次数为7700, 本次损失值为0.25104597210884094
# 训练次数为7800, 本次损失值为0.36462169885635376
# 这是第10轮训练，这轮训练的总损失为146.23109477758408
# Test Accuracy: 72.86%
# 模型已保存
# -----------------------第11轮训练开始啦-------------------------
# 训练次数为7900, 本次损失值为0.3614634871482849
# 训练次数为8000, 本次损失值为0.2962147295475006
# 训练次数为8100, 本次损失值为0.3107374906539917
# 训练次数为8200, 本次损失值为0.4330981969833374
# 训练次数为8300, 本次损失值为0.3049390912055969
# 训练次数为8400, 本次损失值为0.18980014324188232
# 训练次数为8500, 本次损失值为0.39275047183036804
# 训练次数为8600, 本次损失值为0.3826104700565338
# 这是第11轮训练，这轮训练的总损失为155.93339386582375
# Test Accuracy: 73.01%
# 模型已保存
# -----------------------第12轮训练开始啦-------------------------
# 训练次数为8700, 本次损失值为0.3051414489746094
# 训练次数为8800, 本次损失值为0.14865972101688385
# 训练次数为8900, 本次损失值为0.23663975298404694
# 训练次数为9000, 本次损失值为0.36403679847717285
# 训练次数为9100, 本次损失值为0.42089858651161194
# 训练次数为9200, 本次损失值为0.2674126625061035
# 训练次数为9300, 本次损失值为0.16206477582454681
# 这是第12轮训练，这轮训练的总损失为161.24817514419556
# Test Accuracy: 73.45%
# 模型已保存
# -----------------------第13轮训练开始啦-------------------------
# 训练次数为9400, 本次损失值为0.1293562948703766
# 训练次数为9500, 本次损失值为0.1652372181415558
# 训练次数为9600, 本次损失值为0.10096538066864014
# 训练次数为9700, 本次损失值为0.2813500463962555
# 训练次数为9800, 本次损失值为0.21238785982131958
# 训练次数为9900, 本次损失值为0.1768173724412918
# 训练次数为10000, 本次损失值为0.08306293934583664
# 训练次数为10100, 本次损失值为0.3558100461959839
# 这是第13轮训练，这轮训练的总损失为176.12990963459015
# Test Accuracy: 72.71%
# 模型已保存
# -----------------------第14轮训练开始啦-------------------------
# 训练次数为10200, 本次损失值为0.14643043279647827
# 训练次数为10300, 本次损失值为0.1267920732498169
# 训练次数为10400, 本次损失值为0.3165602684020996
# 训练次数为10500, 本次损失值为0.11691096425056458
# 训练次数为10600, 本次损失值为0.10163398832082748
# 训练次数为10700, 本次损失值为0.14967598021030426
# 训练次数为10800, 本次损失值为0.2052219808101654
# 训练次数为10900, 本次损失值为0.155222088098526
# 这是第14轮训练，这轮训练的总损失为187.6013064980507
# Test Accuracy: 72.78%
# 模型已保存
# -----------------------第15轮训练开始啦-------------------------
# 训练次数为11000, 本次损失值为0.13497760891914368
# 训练次数为11100, 本次损失值为0.13094857335090637
# 训练次数为11200, 本次损失值为0.06426195055246353
# 训练次数为11300, 本次损失值为0.11562590301036835
# 训练次数为11400, 本次损失值为0.10510671883821487
# 训练次数为11500, 本次损失值为0.1215536892414093
# 训练次数为11600, 本次损失值为0.13684064149856567
# 训练次数为11700, 本次损失值为0.18713568150997162
# 这是第15轮训练，这轮训练的总损失为196.4869676232338
# Test Accuracy: 72.98%
# 模型已保存
# -----------------------第16轮训练开始啦-------------------------
# 训练次数为11800, 本次损失值为0.20421671867370605
# 训练次数为11900, 本次损失值为0.19429270923137665
# 训练次数为12000, 本次损失值为0.0797252431511879
# 训练次数为12100, 本次损失值为0.16740640997886658
# 训练次数为12200, 本次损失值为0.22057117521762848
# 训练次数为12300, 本次损失值为0.11690075695514679
# 训练次数为12400, 本次损失值为0.1842581331729889
# 训练次数为12500, 本次损失值为0.11719204485416412
# 这是第16轮训练，这轮训练的总损失为210.9207827448845
# Test Accuracy: 73.40%
# 模型已保存
# -----------------------第17轮训练开始啦-------------------------
# 训练次数为12600, 本次损失值为0.1156969666481018
# 训练次数为12700, 本次损失值为0.057157959789037704
# 训练次数为12800, 本次损失值为0.09000945091247559
# 训练次数为12900, 本次损失值为0.13282784819602966
# 训练次数为13000, 本次损失值为0.20153266191482544
# 训练次数为13100, 本次损失值为0.23113277554512024
# 训练次数为13200, 本次损失值为0.10154659301042557
# 这是第17轮训练，这轮训练的总损失为230.48073607683182
# Test Accuracy: 71.76%
# 模型已保存
# -----------------------第18轮训练开始啦-------------------------
# 训练次数为13300, 本次损失值为0.060593001544475555
# 训练次数为13400, 本次损失值为0.07865903526544571
# 训练次数为13500, 本次损失值为0.12240466475486755
# 训练次数为13600, 本次损失值为0.03634851425886154
# 训练次数为13700, 本次损失值为0.08088351041078568
# 训练次数为13800, 本次损失值为0.0436682365834713
# 训练次数为13900, 本次损失值为0.14361679553985596
# 训练次数为14000, 本次损失值为0.1714998334646225
# 这是第18轮训练，这轮训练的总损失为250.49834072589874
# Test Accuracy: 71.93%
# 模型已保存
# -----------------------第19轮训练开始啦-------------------------
# 训练次数为14100, 本次损失值为0.20442579686641693
# 训练次数为14200, 本次损失值为0.14882296323776245
# 训练次数为14300, 本次损失值为0.04871375486254692
# 训练次数为14400, 本次损失值为0.052279941737651825
# 训练次数为14500, 本次损失值为0.042967841029167175
# 训练次数为14600, 本次损失值为0.05290720611810684
# 训练次数为14700, 本次损失值为0.07943165302276611
# 训练次数为14800, 本次损失值为0.06067229434847832
# 这是第19轮训练，这轮训练的总损失为253.39600095152855
# Test Accuracy: 72.87%
# 模型已保存
# -----------------------第20轮训练开始啦-------------------------
# 训练次数为14900, 本次损失值为0.18734434247016907
# 训练次数为15000, 本次损失值为0.014974740333855152
# 训练次数为15100, 本次损失值为0.04313797503709793
# 训练次数为15200, 本次损失值为0.05440903082489967
# 训练次数为15300, 本次损失值为0.05813441425561905
# 训练次数为15400, 本次损失值为0.02374911680817604
# 训练次数为15500, 本次损失值为0.06167641282081604
# 训练次数为15600, 本次损失值为0.154686838388443
# 这是第20轮训练，这轮训练的总损失为265.81738540530205
# Test Accuracy: 72.01%
# 模型已保存
# 完成训练
